# %%
import pandas as pd

# %% [markdown]
# ## Merging New York Times Mask Usage with Twitter/COVID-19 Dataframe

# %%
# Reading in the mask usage csv from the New York Times
maskusage = pd.read_csv('mask-use-by-county.csv')

maskusage.head()
# Out:
#    COUNTYFP  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 0      1001  0.053   0.074      0.134       0.295   0.444
# 1      1003  0.083   0.059      0.098       0.323   0.436
# 2      1005  0.067   0.121      0.120       0.201   0.491
# 3      1007  0.020   0.034      0.096       0.278   0.572
# 4      1009  0.053   0.114      0.180       0.194   0.459

# %%
# Renaming County Code column to match original dataframe
maskusage_new = maskusage.rename(columns={'COUNTYFP': 'FIPS'})

maskusage_new.head()
# Out:
#    FIPS  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 0  1001  0.053   0.074      0.134       0.295   0.444
# 1  1003  0.083   0.059      0.098       0.323   0.436
# 2  1005  0.067   0.121      0.120       0.201   0.491
# 3  1007  0.020   0.034      0.096       0.278   0.572
# 4  1009  0.053   0.114      0.180       0.194   0.459

# %%
# Looking at the dataframe that we will be merging with
tweets_and_c19 = pd.read_csv('tweets_and_c19.csv')

tweets_and_c19.head()
# Out:
#    Unnamed: 0                      county  \
# 0           0  County of San Francisco CA
# 1           1  County of San Francisco CA
# 2           2  County of San Francisco CA
# 3           3  County of San Francisco CA
# 4           4  County of San Francisco CA
#
#                                       original_tweet  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweets_list  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['If you live in supportive housing, you are p...
# 2  ['If you live in supportive housing, you are p...
# 3  ['If you live in supportive housing, you are p...
# 4  ['If you live in supportive housing, you are p...
#
#                                            tweet_str  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweet_slice  \
# 0  bly disabled enough to get the vaccine (or may...
# 1  ill after all this time hatred and anxiety tra...
# 2                            tps://t.co/qWAQiZsJWX']
# 3                            tps://t.co/xHjDwTVEeg']
# 4                            tps://t.co/2gYfKCKW3k']
#
#                                           tweet_text       UID iso2 iso3  ...  \
# 0  'if you live in supportive housing you are pro...  84006075   US  USA  ...
# 1  'robini technolass i have mask fatigue and sti...  84006075   US  USA  ...
# 2      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
# 3      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
# 4      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
#
#    3/7/21  3/8/21 3/9/21 3/10/21 3/11/21  3/12/21  3/13/21 3/14/21  3/15/21  \
# 0   34560   34594  34634   34654   34688    34722    34758   34784    34810
# 1   34560   34594  34634   34654   34688    34722    34758   34784    34810
# 2   34560   34594  34634   34654   34688    34722    34758   34784    34810
# 3   34560   34594  34634   34654   34688    34722    34758   34784    34810
# 4   34560   34594  34634   34654   34688    34722    34758   34784    34810
#
#    3/16/21
# 0    34820
# 1    34820
# 2    34820
# 3    34820
# 4    34820
#
# [5 rows x 438 columns]

# %%
# Merging the Mask Usage dataset and Twitter/COVID dataset
usage_tweet_covid = tweets_and_c19.merge(maskusage_new, on='FIPS')

usage_tweet_covid.head()
# Out:
#    Unnamed: 0                      county  \
# 0           0  County of San Francisco CA
# 1           1  County of San Francisco CA
# 2           2  County of San Francisco CA
# 3           3  County of San Francisco CA
# 4           4  County of San Francisco CA
#
#                                       original_tweet  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweets_list  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['If you live in supportive housing, you are p...
# 2  ['If you live in supportive housing, you are p...
# 3  ['If you live in supportive housing, you are p...
# 4  ['If you live in supportive housing, you are p...
#
#                                            tweet_str  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweet_slice  \
# 0  bly disabled enough to get the vaccine (or may...
# 1  ill after all this time hatred and anxiety tra...
# 2                            tps://t.co/qWAQiZsJWX']
# 3                            tps://t.co/xHjDwTVEeg']
# 4                            tps://t.co/2gYfKCKW3k']
#
#                                           tweet_text       UID iso2 iso3  ...  \
# 0  'if you live in supportive housing you are pro...  84006075   US  USA  ...
# 1  'robini technolass i have mask fatigue and sti...  84006075   US  USA  ...
# 2      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
# 3      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
# 4      'why covid- vaccines could make us mask-free   84006075   US  USA  ...
#
#    3/12/21  3/13/21 3/14/21 3/15/21 3/16/21  NEVER  RARELY SOMETIMES  \
# 0    34722    34758   34784   34810   34820  0.017   0.011     0.035
# 1    34722    34758   34784   34810   34820  0.017   0.011     0.035
# 2    34722    34758   34784   34810   34820  0.017   0.011     0.035
# 3    34722    34758   34784   34810   34820  0.017   0.011     0.035
# 4    34722    34758   34784   34810   34820  0.017   0.011     0.035
#
#    FREQUENTLY  ALWAYS
# 0       0.121   0.817
# 1       0.121   0.817
# 2       0.121   0.817
# 3       0.121   0.817
# 4       0.121   0.817
#
# [5 rows x 443 columns]
