# %%
import pandas as pd

c19cases = pd.read_csv('time_series_covid19_confirmed_US.csv')

c19cases.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 3/7/21  3/8/21  3/9/21  3/10/21  3/11/21  \
# 0  32.539527 -86.644082  ...   6347    6364    6371     6400     6409
# 1  30.727750 -87.722071  ...  19935   19942   19962    20012    20044
# 2  31.868263 -85.387129  ...   2139    2143    2147     2161     2171
# 3  32.996421 -87.125115  ...   2465    2464    2466     2469     2474
# 4  33.982109 -86.567906  ...   6256    6256    6255     6260     6274
#
#    3/12/21  3/13/21  3/14/21  3/15/21  3/16/21
# ...

# %%
#orig county list DO NOT RUN

c19df = c19cases[(c19cases['Province_State'] == 'New York') & (c19cases['Admin2'] == 'Onondaga')]
                 
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Illinois') & (c19cases['Admin2'] == 'Lake')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Virginia') & (c19cases['Admin2'] == 'Manassas Park')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Missouri') & (c19cases['Admin2'] == 'Clay')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Virginia') & (c19cases['Admin2'] == 'Virginia Beach')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Florida') & (c19cases['Admin2'] == 'Pinellas')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Pennsylvania') & (c19cases['Admin2'] == 'Lancaster')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Texas') & (c19cases['Admin2'] == 'Galveston')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Texas') & (c19cases['Admin2'] == 'Harris')])

        
# c19df

# %%
# new dataframe of selected counties
counties = pd.read_csv('county_info_new.csv', index_col = [0]) #note csv file name
counties.rename({'counties': 'county'}, axis='columns', inplace = True)
counties
# Out:
#                   county                 state  populations  ed_rate  tier  \
# 0               New York              New York        69468    0.613     2
# 1          San Francisco            California        17179    0.581     2
# 2                 Hudson            New Jersey        13732    0.423     1
# 3                Suffolk         Massachusetts        12417    0.461     2
# 4           Philadelphia          Pennsylvania        11379    0.297     1
# 5   District of Columbia  District of Columbia         9857    0.585     2
# 6             Alexandria              Virginia         9314    0.631     3
# 7              Baltimore              Maryland         7672    0.394     1
# 8                   Cook              Illinois         5495    0.388     1
# 9              St. Louis              Missouri         5157    0.436     1
# 10             Milwaukee             Wisconsin         3926    0.310     1
# ...

# %%
# CLEANING OF ORIG COUNTY CSV FILE, DO NOT RUN
states = []
counties_lst = []

for index, county in counties.iterrows():
    states.append(county['county'][-2:])
    counties_lst.append(county['county'][0:-3])
    
counties['state'] = states
counties['county'] = counties_lst


counties = counties[['county', 'state', 'populations', 'ed_rate', 'tier', 'lat/lon']]

#counties

# %%
# Collecting COVID-19 data according to the counties listed in county_info_new.csv

c19df = pd.DataFrame()

for index, county in counties.iterrows():
    c19df = c19df.append(c19cases[(c19cases['Province_State'] == str(county['state'])) & 
                          (c19cases['Admin2'] == str(county['county']))])
    
    

c19df

#c19df.to_csv('covid_cases.csv')
# Out:
#            UID iso2 iso3  code3     FIPS                Admin2  \
# 1930  84036061   US  USA    840  36061.0              New York
# 233   84006075   US  USA    840   6075.0         San Francisco
# 1850  84034017   US  USA    840  34017.0                Hudson
# 1277  84025025   US  USA    840  25025.0               Suffolk
# 2380  84042101   US  USA    840  42101.0          Philadelphia
# 337   84011001   US  USA    840  11001.0  District of Columbia
# 3010  84051510   US  USA    840  51510.0            Alexandria
# 1239  84024005   US  USA    840  24005.0             Baltimore
# 640   84017031   US  USA    840  17031.0                  Cook
# 1642  84029189   US  USA    840  29189.0             St. Louis
# 3281  84055079   US  USA    840  55079.0             Milwaukee
# 271   84008031   US  USA    840   8031.0                Denver
# 224   84006059   US  USA    840   6059.0                Orange
# 392   84012103   US  USA    840  12103.0              Pinellas
# ...

# %%
#resetting index for ease of adding columns
c19newdf = pd.DataFrame(c19df)

c19newdf.reset_index()
# Out:
#     index       UID iso2 iso3  code3     FIPS                Admin2  \
# 0    1930  84036061   US  USA    840  36061.0              New York
# 1     233  84006075   US  USA    840   6075.0         San Francisco
# 2    1850  84034017   US  USA    840  34017.0                Hudson
# 3    1277  84025025   US  USA    840  25025.0               Suffolk
# 4    2380  84042101   US  USA    840  42101.0          Philadelphia
# 5     337  84011001   US  USA    840  11001.0  District of Columbia
# 6    3010  84051510   US  USA    840  51510.0            Alexandria
# 7    1239  84024005   US  USA    840  24005.0             Baltimore
# 8     640  84017031   US  USA    840  17031.0                  Cook
# 9    1642  84029189   US  USA    840  29189.0             St. Louis
# 10   3281  84055079   US  USA    840  55079.0             Milwaukee
# 11    271  84008031   US  USA    840   8031.0                Denver
# 12    224  84006059   US  USA    840   6059.0                Orange
# ...

# %%
# Adding different naming conventions to dataframe to match with tweet collection dataframe. 
# NOTE THE ALTERATIONS IN LIST, NAMELY TEST TX LOC. THIS NEW LIST IS IN LINE WITH county_info_new.csv

tweet_locs = pd.Series([
'New York County NY',
 'County of San Francisco CA',
 'Hudson County NJ',
 'Suffolk County MA',
 'Philadelphia County PA',
 'Washington DC',
 'Alexandria VA',
 'Baltimore MD',
 'Cook County IL',
 'St. Louis County MO',
 'Milwaukee County WI',
 'Denver County CO',
 'Orange County CA',
 'Pinellas County FL',
 'Ramsey County MN',
 'Wayne County, MI',
 'Cuyahoga County OH',
 'Dallas County TX',
 'DeKalb County GA',
 'Salt Lake County UT',
 'Marion County IN',
 'Jefferson County KY',
 'Johnson County KS',
 'King County WA'])

c19newdf['county'] = tweet_locs.values

# we can add the education data + any other data contained in the county_info_new.csv at this point

# %%
c19newdf # cols added to end of dataframe, we can change the order if we want
# Out:
#            UID iso2 iso3  code3     FIPS                Admin2  \
# 1930  84036061   US  USA    840  36061.0              New York
# 233   84006075   US  USA    840   6075.0         San Francisco
# 1850  84034017   US  USA    840  34017.0                Hudson
# 1277  84025025   US  USA    840  25025.0               Suffolk
# 2380  84042101   US  USA    840  42101.0          Philadelphia
# 337   84011001   US  USA    840  11001.0  District of Columbia
# 3010  84051510   US  USA    840  51510.0            Alexandria
# 1239  84024005   US  USA    840  24005.0             Baltimore
# 640   84017031   US  USA    840  17031.0                  Cook
# 1642  84029189   US  USA    840  29189.0             St. Louis
# 3281  84055079   US  USA    840  55079.0             Milwaukee
# 271   84008031   US  USA    840   8031.0                Denver
# 224   84006059   US  USA    840   6059.0                Orange
# 392   84012103   US  USA    840  12103.0              Pinellas
# ...

# %% [markdown]
# # Joining dataframes

# %%
tweets = pd.read_csv('cleaned_tweets_finalquery.csv', index_col = [0])

# %%
tweets_and_c19 = tweets.merge(c19newdf, on='county')
tweets_and_c19
# Out:
#                          county  \
# 0    County of San Francisco CA
# 1    County of San Francisco CA
# 2    County of San Francisco CA
# 3    County of San Francisco CA
# 4    County of San Francisco CA
# ..                          ...
# 267              King County WA
# 268              King County WA
# 269              King County WA
# 270              King County WA
# 271              King County WA
#
#                                         original_tweet  \
# 0    ['If you live in supportive housing, you are p...
# 1    ['@robini71 @technolass I have mask fatigue an...
# 2    ['Why COVID-19 vaccines could make us mask-fre...
# 3    ['Why COVID-19 vaccines could make us mask-fre...
# 4    ['Why COVID-19 vaccines could make us mask-fre...
# ..                                                 ...
# 267  ['I never say anything to my cousin anymore bc...
# 268  ['@offgridteacher I’ve eaten indoors but the m...
# 269  ["@RantsByDesign I'm in mask-free TX, where we...
# ...

# %%
#trying to parse for duplicates, doesn't seem to be working
tweets_and_c19.drop_duplicates('original_tweet', inplace = True)

# %%
dates = '1/22/20,1/23/20,1/24/20,1/25/20,1/26/20,1/27/20,1/28/20,1/29/20,1/30/20,1/31/20,2/1/20,2/2/20,2/3/20,2/4/20,2/5/20,2/6/20,2/7/20,2/8/20,2/9/20,2/10/20,2/11/20,2/12/20,2/13/20,2/14/20,2/15/20,2/16/20,2/17/20,2/18/20,2/19/20,2/20/20,2/21/20,2/22/20,2/23/20,2/24/20,2/25/20,2/26/20,2/27/20,2/28/20,2/29/20,3/1/20,3/2/20,3/3/20,3/4/20,3/5/20,3/6/20,3/7/20,3/8/20,3/9/20,3/10/20,3/11/20,3/12/20,3/13/20,3/14/20,3/15/20,3/16/20,3/17/20,3/18/20,3/19/20,3/20/20,3/21/20,3/22/20,3/23/20,3/24/20,3/25/20,3/26/20,3/27/20,3/28/20,3/29/20,3/30/20,3/31/20,4/1/20,4/2/20,4/3/20,4/4/20,4/5/20,4/6/20,4/7/20,4/8/20,4/9/20,4/10/20,4/11/20,4/12/20,4/13/20,4/14/20,4/15/20,4/16/20,4/17/20,4/18/20,4/19/20,4/20/20,4/21/20,4/22/20,4/23/20,4/24/20,4/25/20,4/26/20,4/27/20,4/28/20,4/29/20,4/30/20,5/1/20,5/2/20,5/3/20,5/4/20,5/5/20,5/6/20,5/7/20,5/8/20,5/9/20,5/10/20,5/11/20,5/12/20,5/13/20,5/14/20,5/15/20,5/16/20,5/17/20,5/18/20,5/19/20,5/20/20,5/21/20,5/22/20,5/23/20,5/24/20,5/25/20,5/26/20,5/27/20,5/28/20,5/29/20,5/30/20,5/31/20,6/1/20,6/2/20,6/3/20,6/4/20,6/5/20,6/6/20,6/7/20,6/8/20,6/9/20,6/10/20,6/11/20,6/12/20,6/13/20,6/14/20,6/15/20,6/16/20,6/17/20,6/18/20,6/19/20,6/20/20,6/21/20,6/22/20,6/23/20,6/24/20,6/25/20,6/26/20,6/27/20,6/28/20,6/29/20,6/30/20,7/1/20,7/2/20,7/3/20,7/4/20,7/5/20,7/6/20,7/7/20,7/8/20,7/9/20,7/10/20,7/11/20,7/12/20,7/13/20,7/14/20,7/15/20,7/16/20,7/17/20,7/18/20,7/19/20,7/20/20,7/21/20,7/22/20,7/23/20,7/24/20,7/25/20,7/26/20,7/27/20,7/28/20,7/29/20,7/30/20,7/31/20,8/1/20,8/2/20,8/3/20,8/4/20,8/5/20,8/6/20,8/7/20,8/8/20,8/9/20,8/10/20,8/11/20,8/12/20,8/13/20,8/14/20,8/15/20,8/16/20,8/17/20,8/18/20,8/19/20,8/20/20,8/21/20,8/22/20,8/23/20,8/24/20,8/25/20,8/26/20,8/27/20,8/28/20,8/29/20,8/30/20,8/31/20,9/1/20,9/2/20,9/3/20,9/4/20,9/5/20,9/6/20,9/7/20,9/8/20,9/9/20,9/10/20,9/11/20,9/12/20,9/13/20,9/14/20,9/15/20,9/16/20,9/17/20,9/18/20,9/19/20,9/20/20,9/21/20,9/22/20,9/23/20,9/24/20,9/25/20,9/26/20,9/27/20,9/28/20,9/29/20,9/30/20,10/1/20,10/2/20,10/3/20,10/4/20,10/5/20,10/6/20,10/7/20,10/8/20,10/9/20,10/10/20,10/11/20,10/12/20,10/13/20,10/14/20,10/15/20,10/16/20,10/17/20,10/18/20,10/19/20,10/20/20,10/21/20,10/22/20,10/23/20,10/24/20,10/25/20,10/26/20,10/27/20,10/28/20,10/29/20,10/30/20,10/31/20,11/1/20,11/2/20,11/3/20,11/4/20,11/5/20,11/6/20,11/7/20,11/8/20,11/9/20,11/10/20,11/11/20,11/12/20,11/13/20,11/14/20,11/15/20,11/16/20,11/17/20,11/18/20,11/19/20,11/20/20,11/21/20,11/22/20,11/23/20,11/24/20,11/25/20,11/26/20,11/27/20,11/28/20,11/29/20,11/30/20,12/1/20,12/2/20,12/3/20,12/4/20,12/5/20,12/6/20,12/7/20,12/8/20,12/9/20,12/10/20,12/11/20,12/12/20,12/13/20,12/14/20,12/15/20,12/16/20,12/17/20,12/18/20,12/19/20,12/20/20,12/21/20,12/22/20,12/23/20,12/24/20,12/25/20,12/26/20,12/27/20,12/28/20,12/29/20,12/30/20,12/31/20,1/1/21,1/2/21,1/3/21,1/4/21,1/5/21,1/6/21,1/7/21,1/8/21,1/9/21,1/10/21,1/11/21,1/12/21,1/13/21,1/14/21,1/15/21,1/16/21,1/17/21,1/18/21,1/19/21,1/20/21,1/21/21,1/22/21,1/23/21,1/24/21,1/25/21,1/26/21,1/27/21,1/28/21,1/29/21,1/30/21,1/31/21,2/1/21,2/2/21,2/3/21,2/4/21,2/5/21,2/6/21,2/7/21,2/8/21,2/9/21,2/10/21,2/11/21,2/12/21,2/13/21,2/14/21,2/15/21,2/16/21,2/17/21,2/18/21,2/19/21,2/20/21,2/21/21,2/22/21,2/23/21,2/24/21,2/25/21,2/26/21,2/27/21,2/28/21,3/1/21,3/2/21,3/3/21,3/4/21,3/5/21,3/6/21,3/7/21,3/8/21,3/9/21'
    
dates = dates.split(",")

dates
# Out:
# ['1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
#  '3/23/20',
#  '3/24/20',
#  '3/25/20',
#  '3/26/20',
#  '3/27/20',
#  '3/28/20',
#  '3/29/20',
#  '3/30/20',
#  '3/31/20',
#  '4/1/20',
#  '4/2/20',
# ...

# %%
tweets_and_c19.drop(columns = dates)

tweets_and_c19
# Out:
#                          county  \
# 0    County of San Francisco CA
# 1    County of San Francisco CA
# 2    County of San Francisco CA
# 3    County of San Francisco CA
# 4    County of San Francisco CA
# ..                          ...
# 267              King County WA
# 268              King County WA
# 269              King County WA
# 270              King County WA
# 271              King County WA
#
#                                         original_tweet  \
# 0    ['If you live in supportive housing, you are p...
# 1    ['@robini71 @technolass I have mask fatigue an...
# 2    ['Why COVID-19 vaccines could make us mask-fre...
# 3    ['Why COVID-19 vaccines could make us mask-fre...
# 4    ['Why COVID-19 vaccines could make us mask-fre...
# ..                                                 ...
# 267  ['I never say anything to my cousin anymore bc...
# 268  ['@offgridteacher I’ve eaten indoors but the m...
# 269  ["@RantsByDesign I'm in mask-free TX, where we...
# ...

# %% [markdown]
# ## Merging New York Times Mask Usage with Twitter/COVID-19 Dataframe

# %%
# Reading in the mask usage csv from the New York Times
maskusage = pd.read_csv('mask-use-by-county.csv')

maskusage.head()
# Out:
#    COUNTYFP  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 0      1001  0.053   0.074      0.134       0.295   0.444
# 1      1003  0.083   0.059      0.098       0.323   0.436
# 2      1005  0.067   0.121      0.120       0.201   0.491
# 3      1007  0.020   0.034      0.096       0.278   0.572
# 4      1009  0.053   0.114      0.180       0.194   0.459

# %%
# Renaming County Code column to match original dataframe
maskusage_new = maskusage.rename(columns={'COUNTYFP': 'FIPS'})

maskusage_new.head()
# Out:
#    FIPS  NEVER  RARELY  SOMETIMES  FREQUENTLY  ALWAYS
# 0  1001  0.053   0.074      0.134       0.295   0.444
# 1  1003  0.083   0.059      0.098       0.323   0.436
# 2  1005  0.067   0.121      0.120       0.201   0.491
# 3  1007  0.020   0.034      0.096       0.278   0.572
# 4  1009  0.053   0.114      0.180       0.194   0.459

# %%
# Looking at the dataframe that we will be merging with
tweets_and_c19.head()
# Out:
#                        county  \
# 0  County of San Francisco CA
# 1  County of San Francisco CA
# 2  County of San Francisco CA
# 3  County of San Francisco CA
# 4  County of San Francisco CA
#
#                                       original_tweet  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweets_list  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['If you live in supportive housing, you are p...
# 2  ['If you live in supportive housing, you are p...
# 3  ['If you live in supportive housing, you are p...
# 4  ['If you live in supportive housing, you are p...
#
#                                            tweet_str  \
# 0  ['If you live in supportive housing, you are p...
# ...

# %%
# Merging the Mask Usage dataset and Twitter/COVID dataset
usage_tweet_covid = tweets_and_c19.merge(maskusage_new, on='FIPS')

usage_tweet_covid.head()
# Out:
#                        county  \
# 0  County of San Francisco CA
# 1  County of San Francisco CA
# 2  County of San Francisco CA
# 3  County of San Francisco CA
# 4  County of San Francisco CA
#
#                                       original_tweet  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['@robini71 @technolass I have mask fatigue an...
# 2  ['Why COVID-19 vaccines could make us mask-fre...
# 3  ['Why COVID-19 vaccines could make us mask-fre...
# 4  ['Why COVID-19 vaccines could make us mask-fre...
#
#                                          tweets_list  \
# 0  ['If you live in supportive housing, you are p...
# 1  ['If you live in supportive housing, you are p...
# 2  ['If you live in supportive housing, you are p...
# 3  ['If you live in supportive housing, you are p...
# 4  ['If you live in supportive housing, you are p...
#
#                                            tweet_str  \
# 0  ['If you live in supportive housing, you are p...
# ...
