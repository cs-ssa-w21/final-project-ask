# %%
import pandas as pd

c19cases = pd.read_csv('time_series_covid19_confirmed_US.csv')

c19cases.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 2/25/21  2/26/21  2/27/21  2/28/21  3/1/21  \
# 0  32.539527 -86.644082  ...    6203     6228     6248     6264    6270
# 1  30.727750 -87.722071  ...   19670    19698    19714    19732   19758
# 2  31.868263 -85.387129  ...    2099     2106     2113     2115    2116
# 3  32.996421 -87.125115  ...    2442     2445     2449     2450    2450
# 4  33.982109 -86.567906  ...    6086     6084     6095     6097    6102
#
#    3/2/21  3/3/21  3/4/21  3/5/21  3/6/21
# ...

# %%
#orig county list

c19df = c19cases[(c19cases['Province_State'] == 'New York') & (c19cases['Admin2'] == 'Onondaga')]
                 
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Illinois') & (c19cases['Admin2'] == 'Lake')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Virginia') & (c19cases['Admin2'] == 'Manassas Park')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Missouri') & (c19cases['Admin2'] == 'Clay')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Virginia') & (c19cases['Admin2'] == 'Virginia Beach')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Florida') & (c19cases['Admin2'] == 'Pinellas')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Pennsylvania') & (c19cases['Admin2'] == 'Lancaster')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Texas') & (c19cases['Admin2'] == 'Galveston')])
c19df = c19df.append(c19cases[(c19cases['Province_State'] == 'Texas') & (c19cases['Admin2'] == 'Harris')])

        
# c19df

# %%
# new dataframe of selected counties
counties = pd.read_csv('county_info.csv', index_col = [0])
counties.rename({'counties': 'county'}, axis='columns', inplace = True)
counties
# Out:
#                   county                 state  populations  ed_rate  tier
# 0               New York              New York        69468    0.613     2
# 1                  Kings              New York        35369    0.375     1
# 2                  Bronx              New York        32903    0.201     1
# 3                 Queens              New York        20554    0.322     1
# 4          San Francisco            California        17179    0.581     2
# 5                 Hudson            New Jersey        13732    0.423     1
# 6                Suffolk         Massachusetts        12417    0.461     2
# 7           Philadelphia          Pennsylvania        11379    0.297     1
# 8   District of Columbia  District of Columbia         9857    0.585     2
# 9             Alexandria              Virginia         9314    0.631     3
# 10             Arlington              Virginia         8853    0.753     3
# ...

# %%
states = []
counties_lst = []

for index, county in counties.iterrows():
    states.append(county['county'][-2:])
    counties_lst.append(county['county'][0:-3])
    
counties['state'] = states
counties['county'] = counties_lst


counties = counties[['county', 'state', 'populations', 'ed_rate', 'tier']]

#counties

# %%
c19df = pd.DataFrame()

for index, county in counties.iterrows():
    c19df = c19df.append(c19cases[(c19cases['Province_State'] == str(county['state'])) & 
                          (c19cases['Admin2'] == str(county['county']))])
    
    

c19df

#c19df.to_csv('covid_cases.csv')
# Out:
#       tier         UID iso2 iso3  code3     FIPS                Admin2  \
# 1930     2  84036061.0   US  USA  840.0  36061.0              New York
# 1923     2  84036047.0   US  USA  840.0  36047.0                 Kings
# 1902     2  84036005.0   US  USA  840.0  36005.0                 Bronx
# 1941     2  84036081.0   US  USA  840.0  36081.0                Queens
# 233      2  84006075.0   US  USA  840.0   6075.0         San Francisco
# 1850     2  84034017.0   US  USA  840.0  34017.0                Hudson
# 1277     2  84025025.0   US  USA  840.0  25025.0               Suffolk
# 2380     2  84042101.0   US  USA  840.0  42101.0          Philadelphia
# 337      2  84011001.0   US  USA  840.0  11001.0  District of Columbia
# 3010     2  84051510.0   US  USA  840.0  51510.0            Alexandria
# 3015     2  84051013.0   US  USA  840.0  51013.0             Arlington
# 1943     2  84036085.0   US  USA  840.0  36085.0              Richmond
# ...
